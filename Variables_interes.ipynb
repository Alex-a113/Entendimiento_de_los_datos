# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex-a113/Entendimiento_de_los_datos/blob/main/Variables_interes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
df = pd.read_csv('/content/listings.csv', encoding='latin-1', engine='python')
display(df.head())
# Out:
#      id                        listing_url     scrape_id last_scraped  \
# 0  3344  https://www.airbnb.com/rooms/3344  2.025060e+13   17/06/2025
# 1  3686  https://www.airbnb.com/rooms/3686  2.025060e+13   17/06/2025
# 2  3943  https://www.airbnb.com/rooms/3943  2.025060e+13   17/06/2025
# 3  4197  https://www.airbnb.com/rooms/4197  2.025060e+13   17/06/2025
# 4  4529  https://www.airbnb.com/rooms/4529  2.025060e+13   17/06/2025
#
#             source                                           name  \
# 0      city scrape  White House-Center City, entire 2BR/2BA Condo
# 1      city scrape                                Vita's Hideaway
# 2      city scrape               Historic Rowhouse Near Monuments
# 3      city scrape             Capitol Hill Bedroom walk to Metro
# 4  previous scrape                      Bertina's  House Part One
#
#                                          description  \
# 0  This listing is for full, exclusive-to-the-gue...
# ...

# %%
cols = [
    "id","host_id","latitude","longitude","host_response_rate","host_acceptance_rate",
    "host_total_listings_count","accommodates","bathrooms","beds","price","minimum_nights",
    "maximum_nights","availability_30","availability_60","availability_90","availability_365",
    "number_of_reviews","number_of_reviews_ltm","number_of_reviews_l30d","review_scores_rating",
    "review_scores_accuracy","review_scores_cleanliness","review_scores_checkin",
    "review_scores_communication","review_scores_location","review_scores_value",
    "calculated_host_listings_count","calculated_host_listings_count_entire_homes",
    "calculated_host_listings_count_private_rooms","reviews_per_month",
    "estimated_occupancy_l365d","estimated_revenue_l365d","bedrooms","host_listings_count",
    "calculated_host_listings_count_shared_rooms","minimum_nights_avg_ntm","maximum_nights_avg_ntm",
    "property_type","host_location","host_response_time","host_is_superhost","host_identity_verified",
    "neighbourhood_cleansed","property_type","room_type","first_review","last_review",
    "instant_bookable","has_availability"]

# %%
display(cols[:35])
# Out:
# ['id',
#  'host_id',
#  'latitude',
#  'longitude',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_total_listings_count',
#  'accommodates',
#  'bathrooms',
#  'beds',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'number_of_reviews_l30d',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'reviews_per_month',
#  'estimated_occupancy_l365d',
#  'estimated_revenue_l365d',
#  'bedrooms',
#  'host_listings_count']

# %%
df_selected_cols = df[cols]
df_selected_cols.to_csv('/content/df_selected_cols_exportado.csv', index=False)
print("DataFrame con columnas seleccionadas exportado exitosamente a '/content/df_selected_cols_exportado.csv'")
# Out:
# DataFrame con columnas seleccionadas exportado exitosamente a '/content/df_selected_cols_exportado.csv'
